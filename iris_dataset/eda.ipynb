# %% [markdown]
# # EDA - Iris Flower Dataset

# %% [markdown]
# ```
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
# Id
# SepalLengthCm
# SepalWidthCm
# PetalLengthCm
# PetalWidthCm
# Species
# ```

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("dark")

# %% [markdown]
# ## Load the dataset

# %%
df_original = pd.read_csv("./dataset/iris.csv")

# %% [markdown]
# ## Understanding the data: Basic EDA

# %%
df_original.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df_original.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df_original.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df_original.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df_original.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df_original.shape
# Out:
# (150, 6)

# %%
df_original.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df_original["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df_original.drop(columns=["Id"], inplace=True)

# %%
numeric_col = [c for c in df_original.columns if c != "Species"]
categorical_col = ["Species"]
target_col = "Species"

numeric_col, categorical_col, target_col
# Out:
# (['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],
#  ['Species'],
#  'Species')

# %% [markdown]
# Basic EDA Analysis:
#
# * Shape = (150, 6)
# * No Missing Values
# * Numerical Columns: ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
# * Categorical Column: ['Species']
# * dtypes: float64(4), int64(1), object(1)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Numerical Columns

# %%
output = plt.boxplot(df_original["SepalLengthCm"], meanline=True, showmeans=True)
print(output.keys())
info = df_original["SepalLengthCm"].describe()
median = df_original["SepalLengthCm"].median()
mean = df_original["SepalLengthCm"].mean()
for line in output["medians"] :
    x, y = line.get_xydata()[1]
    plt.annotate(f"Median={median}", [x+0.01, y])

for line in output["means"] :
    x, y = line.get_xydata()[0]
    plt.annotate(f"Mean={mean:.2f}", [x-0.17, y])

plt.grid(True)
# Out:
# dict_keys(['whiskers', 'caps', 'boxes', 'medians', 'fliers', 'means'])

# %%
def boxplots(dataframe: pd.DataFrame, numeric_features: list, target: str, ncols: int=5, nrows: int=5, figsize: tuple=(10,10)) :
    """
     Generates a box plot for all the numeric features present in your dataframe
    """

    fig = plt.figure(figsize=figsize)
    sns.set_theme(font_scale=2)

    for i, col in enumerate(numeric_features) :
        ax = fig.add_subplot(nrows, ncols, i+1)
        sns.boxplot(data=dataframe, x=col, hue=target, orient='h', ax=ax)

    fig.suptitle("Box Plots of Numeric Columns", fontsize=24)
    fig.tight_layout()
    return fig

# %%
fig_box = boxplots(df_original, numeric_col, target=target_col, nrows=2, ncols=2, figsize=(20,15))
fig_box.savefig("results/BoxPlots.jpg")

# %%
fig, ax = plt.subplots(ncols=1, nrows=len(numeric_col), figsize=(8 ,10))

for i, col in enumerate(numeric_col) :
    sns.boxplot(data=df_original, x=col, hue="Species", orient='h', ax=ax[i])
    ax[i].set_title(col)

fig.suptitle("Box Plots of Numeric Columns")
fig.tight_layout()

# %%
def histplots(dataframe: pd.DataFrame, numeric_features: list, target: str, ncols: int=5, nrows: int=5, figsize: tuple=(10,10)) :
    """
     Generates a box plot for all the numeric features present in your dataframe
    """

    fig = plt.figure(figsize=figsize)
    sns.set_theme(font_scale=2)

    for i, col in enumerate(numeric_features) :
        ax = fig.add_subplot(nrows, ncols, i+1)
        sns.histplot(data=dataframe, x=col, ax=ax, kde=True, color="blue", hue=target)

    fig.suptitle("Distribution of Numeric Columns", fontsize=24)
    fig.tight_layout()
    return fig

# %%
fig_hist = histplots(df_original, numeric_col, nrows=2, ncols=2, target=target_col, figsize=(20,15))
fig_hist.savefig("results/HistPlots.jpg")

# %%
fig, ax = plt.subplots(nrows=1, ncols=len(numeric_col), figsize=(15 ,5))

for i, col in enumerate(numeric_col) :    
    sns.histplot(data=df_original, x=col, ax=ax[i], kde=True, color="blue", hue="Species")
    ax[i].set_title(col)

fig.suptitle("Distribution of Numeric Columns")
fig.tight_layout()

# %% [markdown]
# ### Categorical Columns

# %%
target_col = categorical_col[0]
target_col
# Out:
# 'Species'

# %%
df_original[target_col].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.set_theme(font_scale=2)
sns.countplot(data=df_original, x=f"{target_col}", hue=target_col)
plt.title("Count of Each Species", fontsize=24)
plt.xlabel("")
plt.savefig("results/CountPlot.jpg")

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numeric vs Numeric

# %%
plt.figure(figsize=(20, 15))
sns.set_theme(font_scale=2)
sns.heatmap(df_original.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap Matrix", fontsize=24)
plt.savefig("results/CorrelationHeatmap.jpg")

# %% [markdown]
# ### Categorical vs Numeric

# %%
boxplots(df_original, numeric_col, target_col, figsize=(20,20))

# %%
def violinplots(dataframe: pd.DataFrame, numeric_features: list, target: str, ncols: int=5, nrows: int=5, figsize: tuple=(10,10)) :
    """
     Generates a box plot for all the numeric features present in your dataframe
    """

    fig = plt.figure(figsize=figsize)

    for i, col in enumerate(numeric_features) :
        ax = fig.add_subplot(nrows, ncols, i+1)
        sns.violinplot(data=dataframe, x=col, hue=target, orient='h', ax=ax)
        ax.set_title(col, fontsize=20)
        ax.set_xlabel("")

    fig.suptitle("Box Plots of Numeric Columns", fontsize=24)
    fig.tight_layout()
    return fig

# %%
fig_violin = violinplots(df_original, numeric_col, target_col, 2, 2, figsize=(20,15))
fig_violin.savefig("results/ViolinPlots.jpg")

# %%
def stripplots(dataframe: pd.DataFrame, numeric_features: list, target: str, ncols: int=5, nrows: int=5, figsize: tuple=(10,10)) :
    """
     Generates a box plot for all the numeric features present in your dataframe
    """

    fig = plt.figure(figsize=figsize)

    for i, col in enumerate(numeric_features) :
        ax = fig.add_subplot(nrows, ncols, i+1)
        sns.stripplot(data=dataframe, x=col, hue=target, orient='h', ax=ax)
        ax.set_title(col, fontsize=20)
        ax.set_xlabel("")

    fig.suptitle("Box Plots of Numeric Columns", fontsize=24)
    fig.tight_layout()
    return fig

# %%
fig_strip = stripplots(df_original, numeric_col, target_col, 2, 2, figsize=(20,15))
fig_strip.savefig("results/StripPlots.jpg")

# %% [markdown]
# ### Categorical vs Categorical: Nothing in Iris DataSet

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.figure(figsize=(20, 15))
sns.set_theme(font_scale=1.2)
sns.pairplot(df_original, hue=target_col, kind="scatter")
plt.suptitle("Pair Plot", fontsize=24)
plt.savefig("results/PairPlot.jpg")

# %%
sns.heatmap(df_original.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap Matrix')

# %%
sns.catplot(df_original, x="SepalLengthCm", y="SepalWidthCm", hue=target_col, height=5, aspect=2.0)

# %% [markdown]
# ## Outlier Detection

# %% [markdown]
# ### Univariate Detection

# %%
boxplots(df_original, numeric_col, target_col, figsize=(20,20))

# %%
from scipy.stats import zscore

# %%
df_petal_len = pd.DataFrame(zscore(df_original["PetalLengthCm"]))
df_petal_len.columns = ["petal_len"]

# %%
df_original[df_petal_len["petal_len"].abs() > 3].shape
# Out:
# (0, 5)

# %%
df_outlier = pd.DataFrame()

# %%
for col in numeric_col :
    df_outlier[col] = pd.DataFrame(zscore(df_original[col]))
    r, c = df_original[df_outlier[col].abs() > 3].shape
    print(f"Outliers Count ({col}): {r}")
# Out:
# Outliers Count (SepalLengthCm): 0
# Outliers Count (SepalWidthCm): 1
# Outliers Count (PetalLengthCm): 0
# Outliers Count (PetalWidthCm): 0

# %% [markdown]
# ### Multivariate Detection

# %%
from sklearn.ensemble import IsolationForest

df_outlier["Outlier"] = IsolationForest(random_state=42).fit_predict(df_original[numeric_col])
df_outlier[df_outlier["Outlier"] == -1].shape
# Out:
# (38, 5)

# %% [markdown]
# ## Domain Specific Analysis

# %%
map = {
    "Iris-setosa": 0,
    "Iris-versicolor": 1,
    "Iris-virginica": 2
}

df_color = df_original[target_col].map(map)
df_color
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 15))

sns.set_theme(font_scale=1.19)
sns.scatterplot(df_original, x="SepalLengthCm", y="SepalLengthCm", hue=target_col, ax=ax[0,0])
sns.scatterplot(df_original, x="SepalWidthCm", y="SepalWidthCm", hue=target_col, ax=ax[0,1])
sns.scatterplot(df_original, x="PetalLengthCm", y="PetalLengthCm", hue=target_col, ax=ax[1,0])
sns.scatterplot(df_original, x="PetalWidthCm", y="PetalWidthCm", hue=target_col, ax=ax[1,1])

fig.suptitle("How Large is the Species?", fontsize=24)
plt.tight_layout()
plt.legend()
plt.savefig("results/HowLargePlot.jpg")

# %%
df_area = pd.DataFrame()

# %%
df_area["Petal_Area"] = df_original["PetalLengthCm"] * df_original["PetalWidthCm"]
df_area["Sepal_Area"] = df_original["SepalLengthCm"] * df_original["SepalWidthCm"]
df_area["Target"] = df_original[target_col]

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(df_area, x="Petal_Area", y="Sepal_Area", hue="Target", s=200)
plt.legend(loc="lower right")
plt.title("How large is the Flower? (By Area)", fontsize=24)
plt.xlabel("Petal Area", fontsize=20)
plt.ylabel("Sepal Area", fontsize=20)
plt.savefig("results/AreaPlot.jpg")
